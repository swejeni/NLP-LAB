# %%
#SWETHA JENIFER S_225229142
#5-1-23_NLP

# %% [markdown]
# ##### EXCERCISE 1

# %%
import nltk

# %%
nltk.download('wordnet')#WordNet is the lexical database i.e. dictionary for the English language, specifically designed for nlp
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\1mscdsa42\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text="This is Andrew's text, isn't it?"

# %%
tokenizer=nltk.tokenize.WhitespaceTokenizer()
tokens=tokenizer.tokenize(text)
print(len(tokens))
print(tokens)
# Out:
# 6
# ['This', 'is', "Andrew's", 'text,', "isn't", 'it?']

# %%
tokenizer=nltk.tokenize.TreebankWordTokenizer()
tokens=tokenizer.tokenize(text)
print(len(tokens))
print(tokens)
# Out:
# 10
# ['This', 'is', 'Andrew', "'s", 'text', ',', 'is', "n't", 'it', '?']

# %%
tokenizer=nltk.tokenize.WordPunctTokenizer()
tokens=tokenizer.tokenize(text)
print(len(tokens))
print(tokens)
# Out:
# 12
# ['This', 'is', 'Andrew', "'", 's', 'text', ',', 'isn', "'", 't', 'it', '?']

# %% [markdown]
# #### EXERCISE 2

# %%
fname="gift-of-magi.txt"
f=open(fname,'r')
txt=f.read()
f.close()

# %%
#1
tokenizer=nltk.tokenize.WhitespaceTokenizer()
tokens=tokenizer.tokenize(txt)
print(len(tokens))
# Out:
# 2074

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\1mscdsa42\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\1mscdsa42\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#2
text=word_tokenize(txt)
nltk.pos_tag(text)
# Out:
# [('The', 'DT'),
#  ('Gift', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Magi', 'NNP'),
#  ('by', 'IN'),
#  ('O.', 'NNP'),
#  ('Henry', 'NNP'),
#  ('One', 'NNP'),
#  ('dollar', 'NN'),
#  ('and', 'CC'),
#  ('eighty-seven', 'JJ'),
#  ('cents', 'NNS'),
#  ('.', '.'),
#  ('That', 'DT'),
#  ('was', 'VBD'),
#  ('all', 'DT'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('sixty', 'JJ'),
#  ('cents', 'NNS'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('in', 'IN'),
#  ('pennies', 'NNS'),
#  ('.', '.'),
#  ('Pennies', 'NNS'),
#  ('saved', 'VBD'),
#  ('one', 'CD'),
#  ('and', 'CC'),
#  ('two', 'CD'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('time', 'NN'),
#  ('by', 'IN'),
#  ('bulldozing', 'VBG'),
#  ('the', 'DT'),
#  ('grocer', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('vegetable', 'JJ'),
#  ('man', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('butcher', 'NN'),
#  ('until', 'IN'),
#  ('one', 'CD'),
#  ("'s", 'POS'),
#  ('cheeks', 'NN'),
#  ('burned', 'VBD'),
#  ('with', 'IN'),
# ...

# %%
#3
b=nltk.FreqDist(text)
b.most_common(20)
# Out:
# [('.', 141),
#  ('the', 109),
#  (',', 104),
#  ('and', 75),
#  ('a', 65),
#  ('of', 51),
#  ('to', 41),
#  ('``', 30),
#  ("''", 30),
#  ('it', 29),
#  ('was', 27),
#  ('Jim', 26),
#  ('she', 25),
#  ('in', 24),
#  ('her', 24),
#  ('had', 21),
#  ('that', 20),
#  ('Della', 20),
#  ('for', 20),
#  ('at', 19)]

# %%
import re

# %%
#4
jen=re.findall(r"\b\w{10}\b",txt)
jen
# Out:
# ['bulldozing',
#  'imputation',
#  'instigates',
#  'reflection',
#  'mendicancy',
#  'Dillingham',
#  'Dillingham',
#  'prosperity',
#  'Dillingham',
#  'unassuming',
#  'Dillingham',
#  'Dillingham',
#  'introduced',
#  'calculated',
#  'reflection',
#  'conception',
#  'Dillingham',
#  'depreciate',
#  'ransacking',
#  'generosity',
#  'tremendous',
#  'reflection',
#  'critically',
#  'expression',
#  'sentiments',
#  'expression',
#  'difference',
#  'hysterical',
#  'employment',
#  'comforting',
#  'worshipped',
#  'possession',
#  'adornments',
#  'reflection',
#  'uneventful',
#  'sacrificed',
#  'Everywhere']

# %%
print(len(jen))
# Out:
# 37

# %%
#5
swe=re.findall(r"\b\w{11,16}\b",txt)
swe
# Out:
# ['predominating',
#  'description',
#  'appertaining',
#  'contracting',
#  'longitudinal',
#  'brilliantly',
#  'possessions',
#  'grandfather',
#  'proclaiming',
#  'meretricious',
#  'ornamentation',
#  'description',
#  'intoxication',
#  'wonderfully',
#  'disapproval',
#  'laboriously',
#  'inconsequential',
#  'mathematician',
#  'illuminated',
#  'necessitating',
#  'wonderfully',
#  'duplication']

# %%
len(swe)
# Out:
# 22

# %% [markdown]
# #### EXERCISE 3

# %%
jname="austen-emma.txt"
j=open(jname,'r')
etxt=j.read()
j.close()

# %%
etxt[-200:]
# Out:
# 'e deficiencies, the wishes,\nthe hopes, the confidence, the predictions of the small band\nof true friends who witnessed the ceremony, were fully answered\nin the perfect happiness of the union.\n\n\nFINIS\n'

# %%
etoks=nltk.word_tokenize(etxt.lower())

# %%
etoks[-20:]
# Out:
# ['of',
#  'true',
#  'friends',
#  'who',
#  'witnessed',
#  'the',
#  'ceremony',
#  ',',
#  'were',
#  'fully',
#  'answered',
#  'in',
#  'the',
#  'perfect',
#  'happiness',
#  'of',
#  'the',
#  'union',
#  '.',
#  'finis']

# %%
len(etoks)
# Out:
# 191669

# %%
etypes=sorted(set(etoks))

# %%
etypes[-10:]
# Out:
# ['younger',
#  'youngest',
#  'your',
#  'yours',
#  'yourself',
#  'yourself.',
#  'youth',
#  'youthful',
#  'zeal',
#  'zigzags']

# %%
len(etypes)
# Out:
# 8000

# %%
efreq=nltk.FreqDist(etoks)

# %%
efreq['beautiful']
# Out:
# 24

# %%
efreq['the']
# Out:
# 5198

# %%
#Words with prefix and suffix

# %%
[word for word in etoks if word.startswith("un") & word.endswith("able")]
# Out:
# ['unexceptionable',
#  'unsuitable',
#  'unreasonable',
#  'unreasonable',
#  'uncomfortable',
#  'unfavourable',
#  'unexceptionable',
#  'unexceptionable',
#  'uncomfortable',
#  'unpersuadable',
#  'unavoidable',
#  'unreasonable',
#  'uncomfortable',
#  'unsuitable',
#  'unmanageable',
#  'unexceptionable',
#  'unreasonable',
#  'unobjectionable',
#  'unpersuadable',
#  'unsuitable',
#  'unreasonable',
#  'uncomfortable',
#  'unexceptionable',
#  'unpardonable',
#  'unmanageable',
#  'unanswerable',
#  'unfavourable',
#  'unpersuadable',
#  'unaccountable',
#  'undesirable',
#  'unable',
#  'unable',
#  'unpardonable',
#  'unexceptionable',
#  'unreasonable',
#  'unreasonable',
#  'uncomfortable',
#  'unreasonable',
#  'unpardonable',
#  'unaccountable',
#  'unexceptionable',
#  'unreasonable',
#  'unaccountable']

# %%
#Length

# %%
tokenizer = nltk.tokenize.WordPunctTokenizer() 
toke = tokenizer.tokenize (etxt)

# %%
[word for word in toke if len(word)>15]
# Out:
# ['companionableness',
#  'misunderstanding',
#  'incomprehensible',
#  'undistinguishing',
#  'unceremoniousness',
#  'Disingenuousness',
#  'disagreeableness',
#  'misunderstandings',
#  'misunderstandings',
#  'misunderstandings',
#  'misunderstandings',
#  'disinterestedness',
#  'unseasonableness']

# %%
#Average word length

# %%
average=sum(len (word) for word in toke)/len (toke) 
average
# Out:
# 3.755268231589122

# %%
#Word frequency

# %%
from nltk import*
fdiemm = FreqDist (toke)

# %%
 for i,j in fdiemm.items(): 
    if j > 200: 
        print(i,j)
# Out:
# Emma 865
# by 558
# Jane 301
# I 3178
# Woodhouse 313
# , 11454
# and 4672
# with 1187
# a 3004
# to 5183
# some 248
# of 4279
# the 4844
# ; 2199
# had 1606
# - 574
# one 413
# in 2118
# very 1151
# little 354
# or 490
# her 2381
# . 6928
# She 562
# was 2385
# most 243
# father 207
# ' 1007
# s 933
# been 759
# his 1088
# from 535
# too 253
# for 1321
# have 1301
# more 464
# than 415
# an 452
# as 1387
# who 281
# Miss 592
# Mr 1153
# but 1148
# it 2128
# before 243
# any 651
# being 356
# now 273
# they 392
# what 434
# she 1778
# own 301
# The 357
# were 591
# much 478
# think 380
# well 315
# herself 279
# which 552
# at 997
# so 924
# that 1730
# did 335
# not 2101
# -- 1382
# all 835
# .-- 685
# It 400
# first 209
# on 677
# this 418
# thought 226
# no 616
# only 327
# every 398
# Weston 439
# man 233
# there 420
# always 235
# would 815
# be 1970
# how 263
# soon 221
# their 297
# other 220
# such 440
# could 825
# never 347
# them 432
# great 263
# must 564
# Mrs 699
# ...

# %%
#bigrams in Emma

# %%
e2grams = list(nltk.bigrams (toke)) 
e2gramfd = nltk.FreqDist(e2grams)

# %%
e2gramfd
# Out:
# FreqDist({('[', 'Emma'): 1,
#           ('Emma', 'by'): 1,
#           ('by', 'Jane'): 2,
#           ('Jane', 'Austen'): 1,
#           ('Austen', '1816'): 1,
#           ('1816', ']'): 1,
#           (']', 'VOLUME'): 1,
#           ('VOLUME', 'I'): 1,
#           ('I', 'CHAPTER'): 1,
#           ('CHAPTER', 'I'): 3,
#           ('I', 'Emma'): 2,
#           ('Emma', 'Woodhouse'): 5,
#           ('Woodhouse', ','): 110,
#           (',', 'handsome'): 5,
#           ('handsome', ','): 6,
#           (',', 'clever'): 1,
#           ('clever', ','): 7,
#           (',', 'and'): 1879,
#           ('and', 'rich'): 1,
#           ('rich', ','): 3,
#           (',', 'with'): 177,
#           ('with', 'a'): 119,
#           ('a', 'comfortable'): 3,
#           ('comfortable', 'home'): 2,
#           ('home', 'and'): 4,
#           ('and', 'happy'): 8,
#           ('happy', 'disposition'): 1,
#           ('disposition', ','): 5,
#           (',', 'seemed'): 13,
# ...

# %%
#Bigrams

# %%
last_ten = FreqDist(dict(e2gramfd.most_common()[-10:]))
last_ten
# Out:
# FreqDist({('.', 'FINIS'): 1,
#           ('answered', 'in'): 1,
#           ('fully', 'answered'): 1,
#           ('the', 'ceremony'): 1,
#           ('the', 'perfect'): 1,
#           ('the', 'union'): 1,
#           ('union', '.'): 1,
#           ('were', 'fully'): 1,
#           ('who', 'witnessed'): 1,
#           ('witnessed', 'the'): 1})

# %%
#Bigram top frequency

# %%
tokenizer = nltk.tokenize. WhitespaceTokenizer() 
tokes =tokenizer.tokenize(etxt)

# %%
e2grams = list(nltk.bigrams (tokes))
e2gramfd = nltk.FreqDist(e2grams)

# %%
e2gramfd.most_common (20)
# Out:
# [(('to', 'be'), 562),
#  (('of', 'the'), 556),
#  (('in', 'the'), 431),
#  (('I', 'am'), 302),
#  (('had', 'been'), 299),
#  (('could', 'not'), 270),
#  (('it', 'was'), 253),
#  (('she', 'had'), 242),
#  (('to', 'the'), 236),
#  (('have', 'been'), 233),
#  (('of', 'her'), 230),
#  (('I', 'have'), 214),
#  (('and', 'the'), 208),
#  (('would', 'be'), 208),
#  (('she', 'was'), 206),
#  (('do', 'not'), 196),
#  (('of', 'his'), 182),
#  (('that', 'she'), 178),
#  (('to', 'have'), 176),
#  (('such', 'a'), 176)]

# %%
#Bigram frequency count

# %%
for i, j in e2gramfd.items(): 
    if i == ('so', 'happy'): 
        print(i,j)
# Out:
# ('so', 'happy') 3

# %%
#Word following 'so'

# %%
import re 
from collections import Counter

# %%
words = re.findall(r'so+ \w+', open('austen-emma.txt').read()) 
ab = Counter(zip(words))
print(ab)
# Out:
# Counter({('so much',): 95, ('so very',): 76, ('so well',): 30, ('so many',): 27, ('so long',): 27, ('so little',): 20, ('so far',): 17, ('so I',): 14, ('so kind',): 13, ('so good',): 12, ('so often',): 10, ('so soon',): 9, ('so great',): 8, ('so to',): 7, ('so fond',): 7, ('so she',): 7, ('so it',): 6, ('so anxious',): 6, ('so as',): 6, ('so you',): 6, ('so truly',): 6, ('so completely',): 5, ('so obliging',): 5, ('so extremely',): 5, ('so entirely',): 4, ('so happy',): 4, ('so interesting',): 4, ('so fast',): 4, ('so near',): 4, ('so pleased',): 4, ('so few',): 4, ('so that',): 4, ('so strong',): 4, ('so liberal',): 4, ('so miserable',): 4, ('so happily',): 3, ('so proper',): 3, ('so pleasantly',): 3, ('so superior',): 3, ('so warmly',): 3, ('so bad',): 3, ('so odd',): 3, ('so ill',): 3, ('so delighted',): 3, ('so particularly',): 3, ('so easily',): 3, ('so on',): 3, ('so attentive',): 3, ('so fortunate',): 3, ('so glad',): 3, ('so shocked',): 3, ('so at',): 3, ('so obliged',): 2, (
# ...

# %%
# Trigrams

# %%
e3grams = list(nltk.trigrams(tokes)) 
e3gramfd = nltk.FreqDist(e3grams)

# %%
last_ten = FreqDist(dict(e3gramfd.most_common()[-10:]))
last_ten
# Out:
# FreqDist({('answered', 'in', 'the'): 1,
#           ('ceremony,', 'were', 'fully'): 1,
#           ('fully', 'answered', 'in'): 1,
#           ('in', 'the', 'perfect'): 1,
#           ('of', 'the', 'union.'): 1,
#           ('perfect', 'happiness', 'of'): 1,
#           ('the', 'ceremony,', 'were'): 1,
#           ('the', 'perfect', 'happiness'): 1,
#           ('the', 'union.', 'FINIS'): 1,
#           ('were', 'fully', 'answered'): 1})

# %%
#Trigram top frequency

# %%
e3gramfd.most_common(10)
# Out:
# [(('I', 'do', 'not'), 94),
#  (('I', 'am', 'sure'), 75),
#  (('would', 'have', 'been'), 55),
#  (('a', 'great', 'deal'), 55),
#  (('she', 'could', 'not'), 49),
#  (('could', 'not', 'be'), 45),
#  (('she', 'had', 'been'), 44),
#  (('it', 'would', 'be'), 43),
#  (('do', 'not', 'know'), 43),
#  (('Mr.', 'and', 'Mrs.'), 37)]

# %%
#trigram frequency count

# %%
words1 = re.findall(r'so happy to \w+', open('austen-emma.txt').read()) 
print(words1)
# Out:
# []
